# %%
import numpy as np
import pandas as pd

# %%
df_data = pd.read_csv("data.csv")
df_timeline = pd.read_csv("timeline.csv", nrows = 100)
# df_index = pd.read_csv("index.csv", nrows = 100)
df_tsne = pd.read_csv("tsne.csv")

# %%
df_data
# Out:
#                             keywords  year         _material  _height  _width  \
# 0                     sketch,drawing  1890    chalk on paper      850    1340
# 1    Paris,painting,study,Still Life  1886  oil on cardboard     2700    3500
# 2    Paris,painting,study,Still Life  1887     oil on canvas     2710    4080
# 3              Nuenen,sketch,drawing  1884   pencil on paper      750    1240
# 4              Nuenen,sketch,drawing  1884   pencil on paper      750    1240
# ..                               ...   ...               ...      ...     ...
# 960       Nuenen,painting,Still Life  1885     oil on canvas     4320    3130
# 961          Paris,painting,Portrait  1887     oil on canvas     2200    2720
# 962        Paris,painting,Still Life  1887     oil on canvas     3050    4070
# 963        The Hague,drawing,Figures  1882   pencil on paper     2600    4740
# 964            Nuenen,sketch,drawing  1884       pen and ink      750    1240
#
#            _time                                       _description  \
# 0           1890                               Contours of a Figure
# 1           1886                                         Male Torso
# 2           1887                Plaster Cast of a Woman&#39;s Torso
# 3    1884 - 1885                                      Head of a Man
# 4    1884 - 1885            Head of a Woman and an indistinct image
# ..           ...                                                ...
# 960         1885                                   Birds&#39; Nests
# 961         1887                      Portrait of Agostina Segatori
# 962         1887                                              Skull
# 963         1882                              Old Man in a Tailcoat
# 964  1884 - 1885  Peasant Woman Gleaning Ears of Corn (in silhou...
#
#                                        id
# 0    db57c17d-0cb7-4048-8e95-74d969d8b7a7
# 1    972dc0d8-e05f-443b-90e3-9a4aa437dc9b
# 2    91bd6b75-fbbd-4319-8b8b-e7a4f4853ccf
# 3    814d3d6c-afea-470a-b597-ef5ba49eb98b
# 4    dc256110-8a5e-4990-a627-99209b8ffe37
# ..                                    ...
# 960  d0326670-6784-4ae6-8df7-84eb7cf2bb24
# 961  a56fbad4-f824-4e8f-83ab-f1d77eae788b
# 962  6c52c93b-fe46-4d99-8eb5-c05baedd68cf
# 963  5c9276ac-dcc3-42d8-afe6-75cda0b4bd8b
# 964  6e943267-8626-4364-a87d-83ca44eca3ec
#
# [965 rows x 8 columns]

# %%
df_timeline.head(3)
# Out:
#    year           titel                                               text  \
# 0  1864      Early work  Vincent begins drawing his surroundings early,...
# 1  1872  Brotherly love  From The Hague, where Vincent is living and wo...
# 2  1873   Moving abroad  In 1873, Vincent is moved to the London branch...
#
#                                                extra  link  kategorie
# 0  The family van Gogh lives in the small town Zu...   NaN        NaN
# 1  It was Theo who advised Vincent to take on a c...   NaN        NaN
# 2  Far away from his family, he feels lonely and ...   NaN        NaN

# %%
# df_index.head(3)

# %%
df_tsne.head(3)
# Out:
#                                      id         x         y
# 0  000c8fad-0cd0-4b94-a7cb-07b9244374d3 -0.316998  0.002063
# 1  00109cb3-6fd8-4cbf-aec5-bc9afa154438  0.740327  0.338480
# 2  00526ee8-443d-4447-b9c8-2827450bdd5b -0.213677 -0.599358

# %%
df_ours = pd.read_csv("full_dataset.csv", index_col= 0)
df_ours
# Out:
#             date                                     song  \
# 0     2000-01-01  A Country Boy Can Survive (Y2K Version)
# 1     2000-01-01                             I Wanna Know
# 2     2000-01-01                        The Quittin' Kind
# 3     2000-01-01      Show Me The Meaning Of Being Lonely
# 4     2000-01-01                                This Gift
# ...          ...                                      ...
# 9181  2022-01-01                                  Hibachi
# 9182  2022-01-01                                 Thailand
# 9183  2022-01-01                              Do It To It
# 9184  2022-01-01      Christmas Isn't Canceled (Just You)
# 9185  2022-01-01                               25 Million
#
#                                                 artist  peak-rank  \
# 0     Chad Brock With Hank Williams Jr. & George Jones         75
# 1                                                  Joe          4
# 2                                           Joe Diffie         90
# 3                                      Backstreet Boys          6
# 4                                           98 Degrees         49
# ...                                                ...        ...
# 9181     Roddy Ricch Featuring Kodak Black & 21 Savage         91
# 9182                                       Roddy Ricch         95
# 9183                          Acraze Featuring Cherish         97
# 9184                                    Kelly Clarkson         79
# 9185                                       Roddy Ricch         77
#
#       weeks-on-board                                             genres  \
# 0                  3  ['american', 'country', 'country music royalty...
# 1                 44  ['american', 'bebop', 'death by liver cancer',...
# 2                  6                   ['country', 'death by covid-19']
# 3                 24  ['american', 'boy band', 'boy group', 'dance-p...
# 4                  3  ['adult contemporary', 'american', 'boy band',...
# ...              ...                                                ...
# 9181               1                      ['english', 'hip hop', 'rap']
# 9182               1                      ['english', 'hip hop', 'rap']
# 9183               1                                            Unknown
# 9184               1  ['a filk artist', 'american idol', 'dance-pop'...
# 9185               1                      ['english', 'hip hop', 'rap']
#
#                                         track  \
# 0     A Country Boy Can Survive (Y2K Version)
# 1                                I Wanna Know
# 2                           The Quittin' Kind
# 3         Show Me The Meaning Of Being Lonely
# 4                                     Unknown
# ...                                       ...
# 9181                                  Unknown
# 9182                                  Unknown
# 9183                                  Unknown
# 9184                                  Unknown
# 9185                                  Unknown
#
#                                        uri danceability   energy  ...  \
# 0     spotify:track:5pinOKTQyPCPpgjIOKVFY3        0.669    0.592  ...
# 1     spotify:track:1m2xMsxbtxv21Brome189p        0.725    0.487  ...
# 2     spotify:track:4u6U5nwYHok67BBymI9ldh        0.595    0.904  ...
# 3     spotify:track:3BsaRV5QIulYz2lV9WWa8T         0.63    0.625  ...
# 4                                  Unknown      Unknown  Unknown  ...
# ...                                    ...          ...      ...  ...
# 9181                               Unknown      Unknown  Unknown  ...
# 9182                               Unknown      Unknown  Unknown  ...
# 9183                               Unknown      Unknown  Unknown  ...
# 9184                               Unknown      Unknown  Unknown  ...
# 9185                               Unknown      Unknown  Unknown  ...
#
#      acousticness instrumentalness liveness  valence    tempo duration_ms  \
# 0           0.166              0.0    0.114     0.51   75.938    237667.0
# 1            0.26         1.09e-05    0.431    0.599  136.086    296693.0
# 2            0.03         4.43e-05    0.397      0.6  102.002    207467.0
# 3           0.231              0.0   0.0765    0.683  167.998    234960.0
# 4         Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
# ...           ...              ...      ...      ...      ...         ...
# 9181      Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
# 9182      Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
# 9183      Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
# 9184      Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
# 9185      Unknown          Unknown  Unknown  Unknown  Unknown     Unknown
#
#      time_signature chorus_hit sections   target
# 0               4.0   23.61273     11.0      1.0
# 1               4.0   30.12501     12.0      1.0
# 2               4.0   39.45951      9.0      1.0
# 3               4.0    28.3789     13.0      1.0
# 4           Unknown    Unknown  Unknown  Unknown
# ...             ...        ...      ...      ...
# 9181        Unknown    Unknown  Unknown  Unknown
# 9182        Unknown    Unknown  Unknown  Unknown
# 9183        Unknown    Unknown  Unknown  Unknown
# 9184        Unknown    Unknown  Unknown  Unknown
# 9185        Unknown    Unknown  Unknown  Unknown
#
# [9186 rows x 24 columns]

# %%
df_ours['year'] = df_ours.date.apply(lambda x: int(x[:4]))

# %% [markdown]
# ID naming

# %%
df_ours['id'] = df_ours['song'] + " by " + df_ours['artist']

# %%
df_ours['id'] = df_ours['id'].apply(lambda x: x.replace(" ", "_").replace("/","_"))

# %%
df_ours
# Out:
#             date                                     song  \
# 0     2000-01-01  A Country Boy Can Survive (Y2K Version)
# 1     2000-01-01                             I Wanna Know
# 2     2000-01-01                        The Quittin' Kind
# 3     2000-01-01      Show Me The Meaning Of Being Lonely
# 4     2000-01-01                                This Gift
# ...          ...                                      ...
# 9181  2022-01-01                                  Hibachi
# 9182  2022-01-01                                 Thailand
# 9183  2022-01-01                              Do It To It
# 9184  2022-01-01      Christmas Isn't Canceled (Just You)
# 9185  2022-01-01                               25 Million
#
#                                                 artist  peak-rank  \
# 0     Chad Brock With Hank Williams Jr. & George Jones         75
# 1                                                  Joe          4
# 2                                           Joe Diffie         90
# 3                                      Backstreet Boys          6
# 4                                           98 Degrees         49
# ...                                                ...        ...
# 9181     Roddy Ricch Featuring Kodak Black & 21 Savage         91
# 9182                                       Roddy Ricch         95
# 9183                          Acraze Featuring Cherish         97
# 9184                                    Kelly Clarkson         79
# 9185                                       Roddy Ricch         77
#
#       weeks-on-board                                             genres  \
# 0                  3  ['american', 'country', 'country music royalty...
# 1                 44  ['american', 'bebop', 'death by liver cancer',...
# 2                  6                   ['country', 'death by covid-19']
# 3                 24  ['american', 'boy band', 'boy group', 'dance-p...
# 4                  3  ['adult contemporary', 'american', 'boy band',...
# ...              ...                                                ...
# 9181               1                      ['english', 'hip hop', 'rap']
# 9182               1                      ['english', 'hip hop', 'rap']
# 9183               1                                            Unknown
# 9184               1  ['a filk artist', 'american idol', 'dance-pop'...
# 9185               1                      ['english', 'hip hop', 'rap']
#
#                                         track  \
# 0     A Country Boy Can Survive (Y2K Version)
# 1                                I Wanna Know
# 2                           The Quittin' Kind
# 3         Show Me The Meaning Of Being Lonely
# 4                                     Unknown
# ...                                       ...
# 9181                                  Unknown
# 9182                                  Unknown
# 9183                                  Unknown
# 9184                                  Unknown
# 9185                                  Unknown
#
#                                        uri danceability   energy  ...  \
# 0     spotify:track:5pinOKTQyPCPpgjIOKVFY3        0.669    0.592  ...
# 1     spotify:track:1m2xMsxbtxv21Brome189p        0.725    0.487  ...
# 2     spotify:track:4u6U5nwYHok67BBymI9ldh        0.595    0.904  ...
# 3     spotify:track:3BsaRV5QIulYz2lV9WWa8T         0.63    0.625  ...
# 4                                  Unknown      Unknown  Unknown  ...
# ...                                    ...          ...      ...  ...
# 9181                               Unknown      Unknown  Unknown  ...
# 9182                               Unknown      Unknown  Unknown  ...
# 9183                               Unknown      Unknown  Unknown  ...
# 9184                               Unknown      Unknown  Unknown  ...
# 9185                               Unknown      Unknown  Unknown  ...
#
#      liveness  valence    tempo duration_ms time_signature chorus_hit  \
# 0       0.114     0.51   75.938    237667.0            4.0   23.61273
# 1       0.431    0.599  136.086    296693.0            4.0   30.12501
# 2       0.397      0.6  102.002    207467.0            4.0   39.45951
# 3      0.0765    0.683  167.998    234960.0            4.0    28.3789
# 4     Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
# ...       ...      ...      ...         ...            ...        ...
# 9181  Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
# 9182  Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
# 9183  Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
# 9184  Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
# 9185  Unknown  Unknown  Unknown     Unknown        Unknown    Unknown
#
#      sections   target  year  \
# 0        11.0      1.0  2000
# 1        12.0      1.0  2000
# 2         9.0      1.0  2000
# 3        13.0      1.0  2000
# 4     Unknown  Unknown  2000
# ...       ...      ...   ...
# 9181  Unknown  Unknown  2022
# 9182  Unknown  Unknown  2022
# 9183  Unknown  Unknown  2022
# 9184  Unknown  Unknown  2022
# 9185  Unknown  Unknown  2022
#
#                                                      id
# 0     A_Country_Boy_Can_Survive_(Y2K_Version)_by_Cha...
# 1                                   I_Wanna_Know_by_Joe
# 2                       The_Quittin'_Kind_by_Joe_Diffie
# 3     Show_Me_The_Meaning_Of_Being_Lonely_by_Backstr...
# 4                               This_Gift_by_98_Degrees
# ...                                                 ...
# 9181  Hibachi_by_Roddy_Ricch_Featuring_Kodak_Black_&...
# 9182                            Thailand_by_Roddy_Ricch
# 9183            Do_It_To_It_by_Acraze_Featuring_Cherish
# 9184  Christmas_Isn't_Canceled_(Just_You)_by_Kelly_C...
# 9185                          25_Million_by_Roddy_Ricch
#
# [9186 rows x 26 columns]

# %%
df_data.keywords
# Out:
# 0                       sketch,drawing
# 1      Paris,painting,study,Still Life
# 2      Paris,painting,study,Still Life
# 3                Nuenen,sketch,drawing
# 4                Nuenen,sketch,drawing
#                     ...
# 960         Nuenen,painting,Still Life
# 961            Paris,painting,Portrait
# 962          Paris,painting,Still Life
# 963          The Hague,drawing,Figures
# 964              Nuenen,sketch,drawing
# Name: keywords, Length: 965, dtype: object

# %%
df_ours.genres.apply(lambda x: ",".join(x))
# Out:
# 0       [,',a,m,e,r,i,c,a,n,',,, ,',c,o,u,n,t,r,y,',,,...
# 1       [,',a,m,e,r,i,c,a,n,',,, ,',b,e,b,o,p,',,, ,',...
# 2       [,',c,o,u,n,t,r,y,',,, ,',d,e,a,t,h, ,b,y, ,c,...
# 3       [,',a,m,e,r,i,c,a,n,',,, ,',b,o,y, ,b,a,n,d,',...
# 4       [,',a,d,u,l,t, ,c,o,n,t,e,m,p,o,r,a,r,y,',,, ,...
#                               ...
# 9181    [,',e,n,g,l,i,s,h,',,, ,',h,i,p, ,h,o,p,',,, ,...
# 9182    [,',e,n,g,l,i,s,h,',,, ,',h,i,p, ,h,o,p,',,, ,...
# 9183                                        U,n,k,n,o,w,n
# 9184    [,',a, ,f,i,l,k, ,a,r,t,i,s,t,',,, ,',a,m,e,r,...
# 9185    [,',e,n,g,l,i,s,h,',,, ,',h,i,p, ,h,o,p,',,, ,...
# Name: genres, Length: 9186, dtype: object

# %%
# df_ours

# %%
df_ours['keywords'] = df_ours.genres.apply(lambda x: x.replace("[", "").replace(']', "").replace("'", ""))

# %%
df_ours
# Out:
#             date                                     song  \
# 0     2000-01-01  A Country Boy Can Survive (Y2K Version)
# 1     2000-01-01                             I Wanna Know
# 2     2000-01-01                        The Quittin' Kind
# 3     2000-01-01      Show Me The Meaning Of Being Lonely
# 4     2000-01-01                                This Gift
# ...          ...                                      ...
# 9181  2022-01-01                                  Hibachi
# 9182  2022-01-01                                 Thailand
# 9183  2022-01-01                              Do It To It
# 9184  2022-01-01      Christmas Isn't Canceled (Just You)
# 9185  2022-01-01                               25 Million
#
#                                                 artist  peak-rank  \
# 0     Chad Brock With Hank Williams Jr. & George Jones         75
# 1                                                  Joe          4
# 2                                           Joe Diffie         90
# 3                                      Backstreet Boys          6
# 4                                           98 Degrees         49
# ...                                                ...        ...
# 9181     Roddy Ricch Featuring Kodak Black & 21 Savage         91
# 9182                                       Roddy Ricch         95
# 9183                          Acraze Featuring Cherish         97
# 9184                                    Kelly Clarkson         79
# 9185                                       Roddy Ricch         77
#
#       weeks-on-board                                             genres  \
# 0                  3  ['american', 'country', 'country music royalty...
# 1                 44  ['american', 'bebop', 'death by liver cancer',...
# 2                  6                   ['country', 'death by covid-19']
# 3                 24  ['american', 'boy band', 'boy group', 'dance-p...
# 4                  3  ['adult contemporary', 'american', 'boy band',...
# ...              ...                                                ...
# 9181               1                      ['english', 'hip hop', 'rap']
# 9182               1                      ['english', 'hip hop', 'rap']
# 9183               1                                            Unknown
# 9184               1  ['a filk artist', 'american idol', 'dance-pop'...
# 9185               1                      ['english', 'hip hop', 'rap']
#
#                                         track  \
# 0     A Country Boy Can Survive (Y2K Version)
# 1                                I Wanna Know
# 2                           The Quittin' Kind
# 3         Show Me The Meaning Of Being Lonely
# 4                                     Unknown
# ...                                       ...
# 9181                                  Unknown
# 9182                                  Unknown
# 9183                                  Unknown
# 9184                                  Unknown
# 9185                                  Unknown
#
#                                        uri danceability   energy  ...  \
# 0     spotify:track:5pinOKTQyPCPpgjIOKVFY3        0.669    0.592  ...
# 1     spotify:track:1m2xMsxbtxv21Brome189p        0.725    0.487  ...
# 2     spotify:track:4u6U5nwYHok67BBymI9ldh        0.595    0.904  ...
# 3     spotify:track:3BsaRV5QIulYz2lV9WWa8T         0.63    0.625  ...
# 4                                  Unknown      Unknown  Unknown  ...
# ...                                    ...          ...      ...  ...
# 9181                               Unknown      Unknown  Unknown  ...
# 9182                               Unknown      Unknown  Unknown  ...
# 9183                               Unknown      Unknown  Unknown  ...
# 9184                               Unknown      Unknown  Unknown  ...
# 9185                               Unknown      Unknown  Unknown  ...
#
#       valence    tempo duration_ms time_signature chorus_hit sections  \
# 0        0.51   75.938    237667.0            4.0   23.61273     11.0
# 1       0.599  136.086    296693.0            4.0   30.12501     12.0
# 2         0.6  102.002    207467.0            4.0   39.45951      9.0
# 3       0.683  167.998    234960.0            4.0    28.3789     13.0
# 4     Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
# ...       ...      ...         ...            ...        ...      ...
# 9181  Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
# 9182  Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
# 9183  Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
# 9184  Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
# 9185  Unknown  Unknown     Unknown        Unknown    Unknown  Unknown
#
#        target  year                                                 id  \
# 0         1.0  2000  A_Country_Boy_Can_Survive_(Y2K_Version)_by_Cha...
# 1         1.0  2000                                I_Wanna_Know_by_Joe
# 2         1.0  2000                    The_Quittin'_Kind_by_Joe_Diffie
# 3         1.0  2000  Show_Me_The_Meaning_Of_Being_Lonely_by_Backstr...
# 4     Unknown  2000                            This_Gift_by_98_Degrees
# ...       ...   ...                                                ...
# 9181  Unknown  2022  Hibachi_by_Roddy_Ricch_Featuring_Kodak_Black_&...
# 9182  Unknown  2022                            Thailand_by_Roddy_Ricch
# 9183  Unknown  2022            Do_It_To_It_by_Acraze_Featuring_Cherish
# 9184  Unknown  2022  Christmas_Isn't_Canceled_(Just_You)_by_Kelly_C...
# 9185  Unknown  2022                          25_Million_by_Roddy_Ricch
#
#                                                keywords
# 0     american, country, country music royalty, outl...
# 1          american, bebop, death by liver cancer, jazz
# 2                            country, death by covid-19
# 3     american, boy band, boy group, dance-pop, elec...
# 4     adult contemporary, american, boy band, contem...
# ...                                                 ...
# 9181                              english, hip hop, rap
# 9182                              english, hip hop, rap
# 9183                                            Unknown
# 9184  a filk artist, american idol, dance-pop, elect...
# 9185                              english, hip hop, rap
#
# [9186 rows x 27 columns]

# %%
df_ours.to_csv('df_data1.csv', index= False)

# %%
# pd.read_csv("df_data1.csv")

# %%
df_timeline_ours = pd.read_csv("timeline.csv")

# %%
df_timeline_ours1 = df_timeline_ours.append(df_timeline_ours[:7]).reset_index(drop=True)
# Out:
# /var/folders/j0/455vlmts6yl8rk8fz6ztpr480000gn/T/ipykernel_2589/2067459166.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_timeline_ours1 = df_timeline_ours.append(df_timeline_ours[:7]).reset_index(drop=True)

# %%
# df_timeline_ours1

# %%
df_timeline_ours1.year = np.arange(2000, 2023)

# %%
df_timeline_ours1.to_csv("df_timeline_ours1.csv", index = False)

# %% [markdown]
# Generate template images

# %%
from PIL import Image
img_PIL = Image.open('star_yellow.png')
# img_PIL.show()
rgb_im = img_PIL.convert('RGB')

# %%
for name in df_ours.id:
    rgb_im.save(f'images/{name}.jpg')

# %% [markdown]
# Test for 200 songs

# %%
df_temp_200 = df_ours.sample(200)
# rgb_im.save('images/1.jpg')

# %%
df_temp_200.to_csv("df_temp_200.csv", index = False)

# %%
for name in df_temp_200.id:
    rgb_im.save(f'temp_images/{name}.jpg')
